# %% [markdown]
# SETUP: Install dependencies

# %%
# clone repository and cd to it
git install https://github.com/ccb-hms/sbert-scispacy-tools.git
cd sbert-scispacy-tools

# %%
# !pip install "https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_scibert-0.5.4.tar.gz"
# !pip install -r requirements.txt
# !pip install .
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.0/417.0 MB 3.2 MB/s eta 0:00:0000:0100:03
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 KB 4.3 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 15.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 KB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 16.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.3/411.3 KB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.7/401.7 KB 14.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import ScispaCy NER module

# %%
from scispacy_ner import ScispacyUmlsNer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from scispacy_ner import ScispacyUmlsNer
#       3 myspacy = ScispacyUmlsNer(model="en_core_sci_scibert")
#       5 ents = myspacy.extract_entities(input_text="my dog Milo has the flu")
#
# File ~/Documents/Workspace/sbert-scispacy-interfaces/scispacy_ner.py:3
#       1 import os
#       2 import spacy
# ----> 3 import scispacy
#       4 import logging
#       5 import argparse
#
# ModuleNotFoundError: No module named 'scispacy'

# %% [markdown]
# Find entities in a given string

# %%
myspacy = ScispacyUmlsNer(model="en_core_sci_scibert")
ents = myspacy.extract_entities(input_text="my dog Milo has the flu", output_as_df=True)
print(ents)
